# %% [markdown]
# # Capstone project
# This notebook will be dedicated to Capstone project. In the scope of project, there will be use of geospatial data and clustering.

# %%
import pandas
import numpy
import json, requests

# %%
url = 'https://api.foursquare.com/v2/'

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
params = dict(
    client_id='ZWRMFBTVDUYNIIFCNURVWVABME0CEX0K0YUSAE3ZYYWGMUZQ',
    client_secret='T0GTHKD1XVSIHYZZBUK452R1ZC45Q2GEKEBA4BIOTR5DK1LC',
    v='20180602',
    ll='40.73,-74.01',
    query='coffee'
)

# %%
resp = requests.get(url=url + 'venues/search/', params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5ee9ccd5cb82360791cd8cf0'},
#  'response': {'venues': [{'id': '4876216df964a52011511fe3',
#     'name': "Jack's Stir Brew Coffee",
#     'location': {'address': '138 W 10th St',
#      'crossStreet': 'btwn Greenwich Ave & Waverly Pl',
#      'lat': 40.73451,
#      'lng': -74.00062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73451,
#        'lng': -74.00062}],
#      'distance': 937,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['138 W 10th St (btwn Greenwich Ave & Waverly Pl)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
# ...
